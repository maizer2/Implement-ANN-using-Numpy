# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.init

import numpy

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

print(f'device : {device}')

torch.manual_seed(777)

if device == 'cuda':
    torch.cuda.manual_seed_all(777)
# Out:
# device : cuda

# %%
mnist_train = torchvision.datasets.MNIST(root='Data/MNIST_data',
                                         train=True,
                                         transform=transforms.ToTensor(),
                                         download=True)
mnist_test = torchvision.datasets.MNIST(root='Data/MNIST_data',
                                        train=False,
                                        transform=transforms.ToTensor(),
                                        download=True)

# %%
batch_size = 10

train_loader = torch.utils.data.DataLoader(dataset=mnist_train,
                                           batch_size=batch_size,
                                           shuffle=True,
                                           drop_last=True)

test_loader = torch.utils.data.DataLoader(mnist_test,
                                          batch_size=batch_size,
                                          shuffle=True)

# %%
import matplotlib.pyplot as plt
import numpy as np

data_count = 8

def imshow(img):
    img = img / 2 + 0.5
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

dataiter = iter(train_loader)
images, labels = dataiter.next()

imshow(torchvision.utils.make_grid(images[:data_count]))

print(''.join('%5s ' %[labels[j].item()] for j in range(data_count)))
# Out:
#   [4]   [9]   [1]   [5]   [3]   [3]   [6]   [5]

# %% [markdown]
# numpy 변환하고 데이터 관리

# %%
# kernel_size를 통해 kernel의 크기를 정한다.
# input_data로 
def convolution_data_check(I, K, S, P):

    # 정수가 아니면 계산 안됨
    if (I - K + (2 * P)) % S != 0:
        ValueError(print("Can't Conv Cal, Check Data"))
        print(f"I : {I}, K : {K}, P : {P}, S : {S}")
        print(f"(I - K + (2 * P)) % S = {(I - K + (2 * P)) % S}")
        return False

def convolution_2d(input_data, in_channels, out_channels, kernel_size, stride, padding):

    if True != convolution_data_check(len(input_data[0][0]), kernel_size, stride, padding):
        
        kernel = np.random.rand(kernel_size, kernel_size)
        
        print(kernel)

class layer(conv, pool = 0, activ = 0):
    next

# %%
for data, label in train_loader:
    kernel = np.random.rand()
    ##convolution_2d(data, input, output, kernel_size, stride, padding)
    #layer1 = layer(conv = convolution_2d(data, 1, 6, 3, 1, 1),
    #               pool = pooling()
    #)
    print(data.shape)
# Out:
# torch.Size([100, 1, 28, 28])
# torch.Size([100, 1, 28, 28])
# torch.Size([100, 1, 28, 28])
# torch.Size([100, 1, 28, 28])
# torch.Size([100, 1, 28, 28])
# torch.Size([100, 1, 28, 28])
# torch.Size([100, 1, 28, 28])
# torch.Size([100, 1, 28, 28])
# torch.Size([100, 1, 28, 28])
# torch.Size([100, 1, 28, 28])
# torch.Size([100, 1, 28, 28])
# torch.Size([100, 1, 28, 28])
# torch.Size([100, 1, 28, 28])
# torch.Size([100, 1, 28, 28])
# torch.Size([100, 1, 28, 28])
# torch.Size([100, 1, 28, 28])
# torch.Size([100, 1, 28, 28])
# torch.Size([100, 1, 28, 28])
# torch.Size([100, 1, 28, 28])
# torch.Size([100, 1, 28, 28])
# torch.Size([100, 1, 28, 28])
# torch.Size([100, 1, 28, 28])
# torch.Size([100, 1, 28, 28])
# torch.Size([100, 1, 28, 28])
# torch.Size([100, 1, 28, 28])
# torch.Size([100, 1, 28, 28])
# torch.Size([100, 1, 28, 28])
# torch.Size([100, 1, 28, 28])
# torch.Size([100, 1, 28, 28])
# torch.Size([100, 1, 28, 28])
# torch.Size([100, 1, 28, 28])
# torch.Size([100, 1, 28, 28])
# ...
